# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import pickle
import json
import re

from datetime import datetime, timedelta
import time
import os

import pickle
import joblib

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Load all data
#
# Load a subset of the dublin bus data.

# %%
def get_bus_data(line=None, direction=None, show_tables=False):
    
    name = "MasterCleanedLeaving&TripsDataCombined.feather"
    return pd.read_feather(name)

# %%
all_data = get_bus_data()
all_data.head(2)
# Out:
#    index DAYOFSERVICE   TRIPID PROGRNUMBER STOPPOINTID  PLANNEDTIME_ARR  \
# 0      0   2018-01-01  5972116          12         119            48030
# 1     29   2018-01-01  5972116          13          44            48079
#
#    PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP VEHICLEID LINEID ROUTEID  \
# 0            48030           48012           48012   2693211      1    1_37
# 1            48079           48058           48058   2693211      1    1_37
#
#    DIRECTION  ArrDel  DepDel  Waiting_Time
# 0          1      18      18             0
# 1          1      21      21             0

# %% [markdown]
# ## Partition data on disk

# %% [markdown]
# Loading in all the data to select a subset is very slow, better to save all of it in segments now that can be loaded and acted upon individually.

# %% [markdown]
# Determine which segments already exist, write the remaining ones.

# %%
lines = all_data.LINEID.unique()
directions = all_data.DIRECTION.unique()

segments = set()
for line in lines:
    for direction in directions:
        segments.add((line, direction))

segments = sorted(list(segments))

def get_path(segment):
    line, direction = segment
    return "segments/" + line + "_" + str(direction) + ".feather"

def save_segment(line, direction):
    
    print(f"Filtering segment")
    
    line_mask = all_data.LINEID == line
    dir_mask = all_data.DIRECTION == direction
    current_data = all_data[dir_mask & line_mask].copy()
    
    if len(current_data) == 0:
        print(f"Skipping segment - no data")
        return
    
    print(f"Cleaning segment")
    
    current_data.drop(["ArrDel", "DepDel", "Waiting_Time", "index"], 
           axis=1, inplace=True)
    
    # I'm renaming the columns for convenience, but they can
    # be renamed back later if needed.
    current_data.columns = [
        "date", "trip_id", "stop_sequence", "stop_id", 
        "planned_arr", "planned_dep", "arr", "dep", "vehicle_id", 
        "line_id", "route_id", "direction"
    ]
    
    current_data.sort_values(by=['trip_id', 'date','stop_sequence'], 
                      ascending = [False,True,True], inplace=True)
    
    current_data.reset_index(drop=True, inplace=True)
    
    print(f"Writing segment")
    
    current_data.to_feather(get_path((line, direction)))

def save_all_segments():
    
    print(len(segments), "segments total.")

    todo = set()
    for segment in segments:
        if not os.path.exists(get_path(segment)):
            todo.add(segment)
    todo = sorted(list(todo))

    print(len(segments) - len(todo), "already complete.", len(todo), "remain.")
    
    
    for i, segment in enumerate(todo):

        line, direction = segment
        path = get_path(segment)

        print(f"Working on segment {i+1}/{len(todo)}: {line}, {direction}")
        save_segment(line, direction)

# %%
save_segment("16", 1)
print("Complete")
# Out:
# Filtering segment
# Cleaning segment
# Writing segment
# Complete

# %% [markdown]
# A function for loading a specific route/direction

# %%
def get_bus_data(line, direction):
    
    path = "segments/" + line + "_" + str(direction) + ".feather"
    
    return pd.read_feather(path)

# %%
get_bus_data("16", 1).head(2)
# Out:
#         date  trip_id stop_sequence stop_id  planned_arr  planned_dep    arr  \
# 0 2018-12-27  8591828             1    7347        56880        56880  56891
# 1 2018-12-27  8591828             2    3669        56950        56950  56972
#
#      dep vehicle_id line_id route_id  direction
# 0  56891    1000115      16    16_20          1
# 1  57002    1000115      16    16_20          1

# %% [markdown]
# ## Adding features
#
# Define functions for adding various features, and test them on the test subset of data.

# %%
test_data = get_bus_data("16", 1)
display(len(test_data))
# Out:
# 1557835

# %% [markdown]
# ### Add journey time

# %% [markdown]
# This is the target feature. A row corresponds to a stop in a trips sequence on a date. The journey time is the time taken to arrive at this stop, starting from when the bus **arrived** at the last stop. (Not from when it departed)
#
# Put another way, we're not separating dwell times here, and we are including the dwell for one stop in the time taken to reach the next step.

# %%
def add_journey_time(table):

    journey_times = np.zeros(len(table))
    journey_times[1:] = table.dep.values[1:] - table.arr.values[:-1]

    planned_journey_times = np.zeros(len(table))
    planned_journey_times[1:] = table.planned_dep.values[1:] - table.planned_arr.values[:-1]

    table["journey_time"] = journey_times
    table["planned_journey_time"] = planned_journey_times
    table["delay"] = journey_times - planned_journey_times
    table.drop(["planned_arr", "planned_dep", "dep"], axis=1, inplace=True)

    # Drop rows where the actual time is negative.
    # This includes all rows with sequence 1, naturally!
    # It also includes some rows that seem to be errors in the data.
    labels = table.index[table.journey_time <= 0]
    table.drop(labels, inplace=True)

# %%
test_data_2 = test_data.copy()
add_journey_time(test_data_2)
test_data_2.head(2)
display(len(test_data_2))
# Out:
# 1538748

# %% [markdown]
# ### Add datetime features

# %% [markdown]
# I know I said I tend to default to lists, but because of the size of all the routes put together I rewrote them as numpy statements.
# <br>Not the most readable code, but it is much faster than the list based approach I think and there are so many rows.

# %%
def add_datetime_features(table):

    # General breakdown of time
    
    month = table.date.dt.month.values
    day = table.date.dt.day.values
    hour = np.floor(table.arr.values/3600)
    
    # Are people going to school?

    school = ~((6 <= month) & (month <= 8))

    # Is it rush hour?

    def s(time): # s for "to seconds"
        h, m = int(time[:2]), int(time[3:])
        return h*3600 + m*60

    arr = table.arr.values
    rush_hour = np.full(len(table), False)
    for a, b in [("07:00", "08:30"), ("16:00", "18:00")]:
        rush_hour |= (arr >= s(a)) & (arr <= s(b))

    # Is it a weekend?

    weekday = table.date.dt.weekday.values
    weekend = (weekday == 5) | (weekday == 6)

    # Is it an official holiday?

    holiday_options = [
        '2018-01-01', '2018-03-17', '2018-04-02', '2018-05-07','2018-06-04', 
        '2018-08-06', '2018-10-29', '2018-12-25', '2018-12-26'
    ]

    holiday = np.full(len(table), False)
    for option in holiday_options:
        holiday |= table.date == np.datetime64(option)

    # Add these to the dataframe.

    table["month"] = month
    table["day"] = day
    table["hour"] = hour
    
    table["school"] = school
    table["rush_hour"] = rush_hour
    table["weekend"] = weekend
    table["holiday"] = holiday

# %%
test_data_3 = test_data_2.copy()
add_datetime_features(test_data_3)
test_data_3.head(2)
display(len(test_data_3))
# Out:
# 1538748

# %% [markdown]
# ### Add weather features
#
# Load Met Eireann Historical 2018 weather data. We're only keeping certain columns.

# %%
def get_weather():
    
    weather = pd.read_csv("historic_weather.csv", parse_dates=[0])
    weather = weather[["weather_date", "rain", "temp", "wetb", "wdsp", "vis", "clamt"]]
    
    return weather

# %%
weather = get_weather()
weather.head(2)
display(len(weather))
# Out:
# 8760

# %% [markdown]
# Merge with bus data based on date and hour.

# %%
def merged_with_weather(table):
    
    weather = get_weather()
    weather["date"] = pd.to_datetime(weather.weather_date.dt.date)
    weather["hour"] = weather.weather_date.dt.hour
    weather.drop(["weather_date"], axis=1, inplace=True)
    
    combined = pd.merge(table, weather, on=["date", "hour"])
    return combined

# %%
test_data_4 = merged_with_weather(test_data_3.copy())
test_data_4.head(3)
print(len(test_data_4))
# Out:
# 1533242

# %% [markdown]
# ## Summary of Features & Merging

# %% [markdown]
# A function to summarize adding features and merging with weather.

# %%
def add_features(bus_data):
    
    add_journey_time(bus_data)
    add_datetime_features(bus_data)

    combined_data = merged_with_weather(bus_data)

    return combined_data

# %%
test_data = get_bus_data("16", 1)
test_data = add_features(test_data)
test_data.head()
print(len(test_data))
# Out:
# 1533242

# %% [markdown]
# ## Comparison to Leah's Data

# %%
def get_bus_data2(line, direction):
    
    path = "wholeRoutesLeah/df_" + line + "_" + str(direction) + ".csv"
    
    return pd.read_csv(path, index_col=0)

# %%
data = get_bus_data("16", 1)
data2 = get_bus_data2("16", 1)

# data2 has all the features already added.
data = add_features(data)

# %% [markdown]
# From a basic display, there are some differences to be seen.

# %%
display(data.head(2))
display(data2.head(2))

print("Counts")
print("1:", len(data))
print("2:", len(data2))
# Out:
#         date  trip_id stop_sequence stop_id    arr vehicle_id line_id  \
# 0 2018-12-27  8591828             2    3669  56972    1000115      16
# 1 2018-12-27  8591828             3    7349  57085    1000115      16
#
#   route_id  direction  journey_time  ...  school  rush_hour  weekend  holiday  \
# 0    16_20          1         111.0  ...    True      False    False    False
# 1    16_20          1         113.0  ...    True      False    False    False
#
#    rain  temp  wetb  wdsp    vis  clamt
# 0   0.0   9.3   8.6     5  40000      7
# 1   0.0   9.3   8.6     5  40000      7
#
# [2 rows x 25 columns]
#        index DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID PLANNEDTIME_ARR  \
# 0  114812203   2018-12-27  8591828            2         3669        15:49:10
# 1  114812204   2018-12-27  8591828            3         7349        15:50:03
#
#   PLANNEDTIME_DEP ACTUALTIME_ARR ACTUALTIME_DEP  VEHICLEID  ...  RushHour  \
# 0        15:49:10       15:49:32       15:50:02    1000115  ...         0
# 1        15:50:03       15:51:25       15:51:25    1000115  ...         0
#
#   Weekend  Holiday         weather_date  rain  temp wetb  wdsp    vis  clamt
# 0       0        0  2018-12-27 15:00:00   0.0   9.3  8.6     5  40000      7
# 1       0        0  2018-12-27 15:00:00   0.0   9.3  8.6     5  40000      7
#
# [2 rows x 34 columns]
# Counts
# 1: 1533242
# 2: 1536438

# %% [markdown]
# The column names need to be matched to go further with this.

# %%
display(data.columns); display(data2.columns)
# Out:
# Index(['date', 'trip_id', 'stop_sequence', 'stop_id', 'arr', 'vehicle_id',
#        'line_id', 'route_id', 'direction', 'journey_time',
#        'planned_journey_time', 'delay', 'month', 'day', 'hour', 'school',
#        'rush_hour', 'weekend', 'holiday', 'rain', 'temp', 'wetb', 'wdsp',
#        'vis', 'clamt'],
#       dtype='object')
# Index(['index', 'DAYOFSERVICE', 'TRIPID', 'PROGRNUMBER', 'STOPPOINTID',
#        'PLANNEDTIME_ARR', 'PLANNEDTIME_DEP', 'ACTUALTIME_ARR',
#        'ACTUALTIME_DEP', 'VEHICLEID', 'LINEID', 'ROUTEID', 'DIRECTION',
#        'ArrDel', 'DepDel', 'Waiting_Time', 'priorstops_actualTime_Arr',
#        'JourneyTime', 'planned_journey_time', 'delay', 'Month', 'Day', 'Hour',
#        'School', 'RushHour', 'Weekend', 'Holiday', 'weather_date', 'rain',
#        'temp', 'wetb', 'wdsp', 'vis', 'clamt'],
#       dtype='object')

# %%
data2_v2 = data2.drop(["index", "VEHICLEID", "weather_date"], axis=1)
data2_v2.columns = ["date", "trip_id", "stop_sequence", "stop_id", "planned_arr", "planned_dep", "arr", "dep",
                   "line_id", "route_id", "direction", ]
display(data2_v2.columns)
# Out:
# Index(['TRIPID', 'PROGRNUMBER', 'STOPPOINTID', 'PLANNEDTIME_ARR',
#        'PLANNEDTIME_DEP', 'ACTUALTIME_ARR', 'ACTUALTIME_DEP', 'LINEID',
#        'DIRECTION', 'ArrDel', 'DepDel', 'Waiting_Time',
#        'priorstops_actualTime_Arr', 'JourneyTime', 'planned_journey_time',
#        'delay', 'Month', 'Day', 'Hour', 'School', 'RushHour', 'Weekend',
#        'Holiday', 'rain', 'temp', 'wetb', 'wdsp', 'vis', 'clamt'],
#       dtype='object')

# %%
data2.Waiting_Time
# Out:
# 0          30
# 1           0
# 2           0
# 3           0
# 4           0
#            ..
# 1536433     0
# 1536434     0
# 1536435     0
# 1536436     0
# 1536437     0
# Name: Waiting_Time, Length: 1536438, dtype: int64

# %% [markdown]
# ## Model Training & Eval

# %% [markdown]
# I'm keeping model training & eval in the same notebook. It's not a very long notebook since it's just retracing steps and shortening things.

# %%
# This is the list of features being included here, including the target feature.
# I imagine this will change later.

features = [
    #"journey_time",
    "delay",
    "stop_id",
    "month",
    "day",
    "hour",
    "rain",
    "temp",
    "wetb",
    "wdsp",
    "vis",
    "clamt"
]

target_feature = "delay"
#target_feature = "journey_time"

# The model to be used.

# I don't know if models should be reused, esp. with#
# with random_state being there, hence the function.

get_model = lambda: LinearRegression(copy_X=False)

def prepare_for_training(table):
    
    # Is there a less esoteric way to specify columns to keep
    # with inplace?
    to_remove = set(table.columns) - set(features)
    table.drop(to_remove, axis=1, inplace=True)
    
    y = table[target_feature]
    table.drop(target_feature, axis=1, inplace=True)
    X = table
    
    return X,y
    
    
def train(X, y):
    
    model = get_model()
    model.fit(X, y)
    
    return model
    

def eval_metrics(X, y):
    
    model = get_model()
    
    X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=1)
    model.fit(X_train, y_train)
    
    prediction = model.predict(X_test)
    
    ae = abs(y_test - prediction)
    mae = np.mean(ae)
    mape = np.mean(100*ae/y_test)
    
    return mae, mape


def get_path(line, direction, kind):
    
    ext = "pkl" if kind == "pickle" else "job"
    path = f"pickles/{line}_{direction}.{ext}"
    
    return path


def store(line, direction, model, kind):
    
    path = get_path(line, direction , kind)
    
    with open(path, "wb") as file:
        if kind == "pickle":
            pickle.dump(model, file)
        else:
            joblib.dump(model, file, compress=3)

# %%
def eval_single(line, direction):
    
    data = add_features(get_bus_data(line, direction))

    X, y = prepare_for_training(data)

    model = DecisionTreeRegressor(
        random_state = 10,
        max_depth = 25,
        max_leaf_nodes = 206000
    )
    
    #model = LinearRegression(copy_X=False)
    
    #model = MLPRegressor(random_state=1)
    
    X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=1)
    model.fit(X_train, y_train)
    
    prediction = model.predict(X_test)
    
    ae = abs(y_test - prediction)
    mae = np.mean(ae)
    mape = np.mean(100*ae/y_test)
    
    print("MAE:", mae, "  MAPE:", mape)

# %%
eval_single("16", 1)
# Out:
# MAE: 45.72280904771383   MAPE: 44.272834951004704

# %% [markdown]
# Applying this to all routes

# %%
def get_segments():

    segments = set()
    for name in os.listdir("segments"):
        match = re.match("(\w+)_(\d)\.feather", name)
        if match is None:
            print("Skipping: "  +name)
        line, direction = match.groups()
        segments.add((line, int(direction)))
        
    return segments
    
def store_all(kind):
    
    segments = list(get_segments())
    segments = sorted(segments)
    
    paths = list()
    for line, direction in segments:
        paths.append(get_path(line, direction, kind))
        
    for i, path in enumerate(paths):
        if not os.path.exists(path):
            start_i = i - 1
            break
    else:
        start_i = len(paths) - 1
        
    if start_i == -1:
        start_i = 0
    
    print(len(segments), "total segements.")
    print(start_i, "already done. ", end="")
    print(len(segments) - start_i, " to do.")
    
    for i in range(start_i, len(segments)):
        
        line, direction = segments[i]
        path = paths[i]
        
        print("Segment:", i, f"({line}, {direction})")
        
        data = add_features(get_bus_data(line, direction))
        
        if len(data) < 5:
            print("SKIPPING - ", len(data), "data points")
            continue
        
        X, y = prepare_for_training(data)
        
        mae, mape = eval_metrics(X,y)
        print("MAE:", mae, "  MAPE:", mape)
        
        model = train(X,y)
        store(line, direction, model, kind)

# %%
def get_stored_size(kind):
    
    count = 0
    total_size = 0
    for line, direction in get_segments():
        path = get_path(line, direction, kind)
        if not os.path.exists(path):
            continue
        total_size += os.path.getsize(path)
        count += 1
        
    return total_size, count

# %%
byte_count, count = get_stored_size("pickle")
print(f"Total size: {byte_count/(2**30):.02f}Gb")
print(f"Total count: {count}")
print(f"(Segment count: {len(get_segments())})")
# Out:
# Total size: 0.00Gb
# Total count: 0
# (Segment count: 2)

# %%
store_all("job")
# Out:
# 2 total segements.
# 0 already done. 2  to do.
# Segment: 0 (16, 1)
# MAE: 34.309222715229154   MAPE: inf
# Segment: 1 (46A, 1)
# MAE: 33.60453587969265   MAPE: inf

# %%
def count_records():
    
    segments = list(get_segments())
    
    error_count = 0
    record_counts = list()
    
    for i, (line, direction) in enumerate(segments):
    
        print(f"Checking segment {i+1}/{len(segments)}")
        print("Line:", line, "  Direction:", direction)
    
        try:
            data = get_bus_data(line, direction)
        except:
            error_count += 1
            continue
            
        count = len(data)
        record_counts.append([
            line, direction, count
        ])
        
        print("Count:", count)
    
    result = pd.DataFrame(
        record_counts, columns=["line", "direction", "count"]
    )
    
    return result, error_count

# %%
counts, error_count = count_records()
# Out:
# Checking segment 1/252
# Line: 27   Direction: 1
# Count: 1889983
# Checking segment 2/252
# Line: 41A   Direction: 2
# Count: 21383
# Checking segment 3/252
# Line: 38B   Direction: 2
# Count: 76262
# Checking segment 4/252
# Line: 29A   Direction: 1
# Count: 574003
# Checking segment 5/252
# Line: 42   Direction: 1
# Count: 629663
# Checking segment 6/252
# Line: 40E   Direction: 1
# Count: 13153
# Checking segment 7/252
# Line: 31A   Direction: 2
# Count: 210397
# Checking segment 8/252
# Line: 18   Direction: 2
# Count: 667371
# Checking segment 9/252
# Line: 17A   Direction: 1
# Count: 846350
# Checking segment 10/252
# Line: 41D   Direction: 1
# Count: 192
# Checking segment 11/252
# Line: 66B   Direction: 1
# Count: 239701
# Checking segment 12/252
# Line: 66X   Direction: 2
# Count: 82388
# Checking segment 13/252
# Line: 17   Direction: 2
# Count: 526751
# Checking segment 14/252
# Line: 33   Direction: 2
# Count: 536045
# Checking segment 15/252
# Line: 27X   Direction: 2
# Count: 19638
# Checking segment 16/252
# Line: 116   Direction: 1
# Count: 4837
# Checking segment 17/252
# Line: 79A   Direction: 1
# Count: 287598
# Checking segment 18/252
# Line: 67X   Direction: 1
# Count: 81087
# Checking segment 19/252
# Line: 7A   Direction: 1
# Count: 524788
# Checking segment 20/252
# Line: 25D   Direction: 2
# Count: 15860
# Checking segment 21/252
# Line: 15B   Direction: 2
# Count: 778312
# Checking segment 22/252
# Line: 37   Direction: 1
# Count: 872292
# Checking segment 23/252
# Line: 79   Direction: 1
# Count: 352240
# Checking segment 24/252
# Line: 67   Direction: 1
# Count: 731660
# Checking segment 25/252
# Line: 150   Direction: 2
# Count: 488121
# Checking segment 26/252
# Line: 69   Direction: 2
# Count: 314588
# Checking segment 27/252
# Line: 53   Direction: 1
# Count: 91604
# Checking segment 28/252
# Line: 15D   Direction: 2
# Count: 7123
# Checking segment 29/252
# Line: 44B   Direction: 2
# Count: 27553
# Checking segment 30/252
# Line: 42D   Direction: 2
# Count: 5461
# Checking segment 31/252
# Line: 15   Direction: 1
# Count: 1761240
# Checking segment 32/252
# Line: 41X   Direction: 1
# Count: 39614
# Checking segment 33/252
# Line: 39X   Direction: 2
# Count: 22804
# Checking segment 34/252
# Line: 33B   Direction: 1
# Count: 136545
# Checking segment 35/252
# Line: 41   Direction: 1
# Count: 741088
# Checking segment 36/252
# Line: 44   Direction: 2
# Count: 427989
# Checking segment 37/252
# Line: 123   Direction: 2
# Count: 1000247
# Checking segment 38/252
# Line: 33A   Direction: 1
# Count: 71107
# Checking segment 39/252
# Line: 184   Direction: 1
# Count: 324664
# Checking segment 40/252
# Line: 41B   Direction: 1
# Count: 67092
# Checking segment 41/252
# Line: 83   Direction: 2
# Count: 984642
# Checking segment 42/252
# Line: 65B   Direction: 1
# Count: 355459
# Checking segment 43/252
# Line: 9   Direction: 2
# Count: 1332417
# Checking segment 44/252
# Line: 14   Direction: 1
# Count: 1273952
# Checking segment 45/252
# Line: 151   Direction: 2
# Count: 748745
# Checking segment 46/252
# Line: 130   Direction: 2
# Count: 871582
# Checking segment 47/252
# Line: 39A   Direction: 2
# Count: 1712976
# Checking segment 48/252
# Line: 145   Direction: 1
# Count: 1878097
# Checking segment 49/252
# Line: 161   Direction: 1
# Count: 2523
# Checking segment 50/252
# Line: 49   Direction: 2
# Count: 391739
# Checking segment 51/252
# Line: 25   Direction: 2
# Count: 168011
# Checking segment 52/252
# Line: 122   Direction: 2
# Count: 855531
# Checking segment 53/252
# Line: 40D   Direction: 2
# Count: 533683
# Checking segment 54/252
# Line: 1   Direction: 1
# Count: 625768
# Checking segment 55/252
# Line: 16C   Direction: 1
# Count: 29674
# Checking segment 56/252
# Line: 111   Direction: 2
# Count: 159936
# Checking segment 57/252
# Line: 31B   Direction: 1
# Count: 44149
# Checking segment 58/252
# Line: 51D   Direction: 1
# Count: 9185
# Checking segment 59/252
# Line: 83A   Direction: 2
# Count: 290977
# Checking segment 60/252
# Line: 38D   Direction: 1
# Count: 7070
# Checking segment 61/252
# Line: 40   Direction: 1
# Count: 1885364
# Checking segment 62/252
# Line: 220   Direction: 1
# Count: 166089
# Checking segment 63/252
# Line: 75   Direction: 2
# Count: 725277
# Checking segment 64/252
# Line: 39   Direction: 1
# Count: 679362
# Checking segment 65/252
# Line: 69X   Direction: 2
# Count: 2228
# Checking segment 66/252
# Line: 56A   Direction: 1
# Count: 258264
# Checking segment 67/252
# Line: 26   Direction: 2
# Count: 152402
# Checking segment 68/252
# Line: 68A   Direction: 2
# Count: 7643
# Checking segment 69/252
# Line: 114   Direction: 1
# Count: 118355
# Checking segment 70/252
# Line: 66   Direction: 2
# Count: 467867
# Checking segment 71/252
# Line: 68   Direction: 2
# Count: 323806
# Checking segment 72/252
# Line: 270   Direction: 2
# Count: 92868
# Checking segment 73/252
# Line: 54A   Direction: 2
# Count: 351334
# Checking segment 74/252
# Line: 47   Direction: 1
# Count: 275450
# Checking segment 75/252
# Line: 140   Direction: 1
# Count: 919949
# Checking segment 76/252
# Line: 84   Direction: 2
# Count: 420691
# Checking segment 77/252
# Line: 25A   Direction: 2
# Count: 512300
# Checking segment 78/252
# Line: 44B   Direction: 1
# Count: 31932
# Checking segment 79/252
# Line: 7D   Direction: 1
# Count: 11345
# Checking segment 80/252
# Line: 185   Direction: 2
# Count: 90616
# Checking segment 81/252
# Line: 11   Direction: 2
# Count: 821263
# Checking segment 82/252
# Line: 43   Direction: 1
# Count: 379971
# Checking segment 83/252
# Line: 25B   Direction: 2
# Count: 414202
# Checking segment 84/252
# Line: 142   Direction: 2
# Count: 66011
# Checking segment 85/252
# Line: 77X   Direction: 2
# Count: 13743
# Checking segment 86/252
# Line: 45A   Direction: 2
# Count: 457447
# Checking segment 87/252
# Line: 31A   Direction: 1
# Count: 189173
# Checking segment 88/252
# Line: 31   Direction: 2
# Count: 621421
# Checking segment 89/252
# Line: 18   Direction: 1
# Count: 516211
# Checking segment 90/252
# Line: 33X   Direction: 2
# Count: 54820
# Checking segment 91/252
# Line: 59   Direction: 2
# Count: 110114
# Checking segment 92/252
# Line: 17   Direction: 1
# Count: 515834
# Checking segment 93/252
# Line: 33   Direction: 1
# Count: 521885
# Checking segment 94/252
# Line: 84A   Direction: 2
# Count: 73041
# Checking segment 95/252
# Line: 76   Direction: 2
# Count: 339198
# Checking segment 96/252
# Line: 27X   Direction: 1
# Count: 19079
# Checking segment 97/252
# Line: 4   Direction: 2
# Count: 1038605
# Checking segment 98/252
# Line: 25D   Direction: 1
# Count: 22720
# Checking segment 99/252
# Line: 7D   Direction: 2
# Count: 25729
# Checking segment 100/252
# Line: 239   Direction: 2
# Count: 94891
# Checking segment 101/252
# Line: 15B   Direction: 1
# Count: 771367
# Checking segment 102/252
# Line: 27   Direction: 2
# Count: 1831881
# Checking segment 103/252
# Line: 32X   Direction: 1
# Count: 20632
# Checking segment 104/252
# Line: 38   Direction: 1
# Count: 444698
# Checking segment 105/252
# Line: 32   Direction: 1
# Count: 395756
# Checking segment 106/252
# Line: 40E   Direction: 2
# Count: 14859
# Checking segment 107/252
# Line: 16D   Direction: 1
# Count: 5291
# Checking segment 108/252
# Line: 41D   Direction: 2
# Count: 283
# Checking segment 109/252
# Line: 42D   Direction: 1
# Count: 4844
# Checking segment 110/252
# Line: 66B   Direction: 2
# Count: 190127
# Checking segment 111/252
# Line: 63   Direction: 2
# Count: 261365
# Checking segment 112/252
# Line: 120   Direction: 1
# Count: 409174
# Checking segment 113/252
# Line: 7   Direction: 1
# Count: 453016
# Checking segment 114/252
# Line: 7A   Direction: 2
# Count: 657512
# Checking segment 115/252
# Line: 70   Direction: 2
# Count: 270339
# Checking segment 116/252
# Line: 123   Direction: 1
# Count: 943556
# Checking segment 117/252
# Line: 16   Direction: 1
# Count: 1557835
# Checking segment 118/252
# Line: 15A   Direction: 1
# Count: 591803
# Checking segment 119/252
# Line: 40B   Direction: 2
# Count: 53808
# Checking segment 120/252
# Line: 37   Direction: 2
# Count: 492635
# Checking segment 121/252
# Line: 67   Direction: 2
# Count: 571440
# Checking segment 122/252
# Line: 31D   Direction: 1
# Count: 5722
# Checking segment 123/252
# Line: 33D   Direction: 1
# Count: 3049
# Checking segment 124/252
# Line: 9   Direction: 1
# Count: 1252704
# Checking segment 125/252
# Line: 84X   Direction: 1
# Count: 27908
# Checking segment 126/252
# Line: 27A   Direction: 2
# Count: 350830
# Checking segment 127/252
# Line: 130   Direction: 1
# Count: 849013
# Checking segment 128/252
# Line: 77A   Direction: 2
# Count: 1062443
# Checking segment 129/252
# Line: 236   Direction: 1
# Count: 15122
# Checking segment 130/252
# Line: 39A   Direction: 1
# Count: 1531987
# Checking segment 131/252
# Line: 14C   Direction: 2
# Count: 20019
# Checking segment 132/252
# Line: 61   Direction: 2
# Count: 233551
# Checking segment 133/252
# Line: 76A   Direction: 1
# Count: 21051
# Checking segment 134/252
# Line: 15   Direction: 2
# Count: 1781706
# Checking segment 135/252
# Line: 25X   Direction: 2
# Count: 8008
# Checking segment 136/252
# Line: 122   Direction: 1
# Count: 832950
# Checking segment 137/252
# Line: 118   Direction: 2
# Count: 5957
# Checking segment 138/252
# Line: 38A   Direction: 1
# Count: 327341
# Checking segment 139/252
# Line: 40D   Direction: 1
# Count: 572341
# Checking segment 140/252
# Line: 33B   Direction: 2
# Count: 124181
# Checking segment 141/252
# Line: 7B   Direction: 2
# Count: 64761
# Checking segment 142/252
# Line: 238   Direction: 1
# Count: 94047
# Checking segment 143/252
# Line: 102   Direction: 1
# Count: 439915
# Checking segment 144/252
# Line: 46A   Direction: 1
# Count: 2033310
# Checking segment 145/252
# Line: 75   Direction: 1
# Count: 676884
# Checking segment 146/252
# Line: 41C   Direction: 2
# Count: 723675
# Checking segment 147/252
# Line: 66A   Direction: 2
# Count: 174554
# Checking segment 148/252
# Line: 70D   Direction: 2
# Count: 5562
# Checking segment 149/252
# Line: 38B   Direction: 1
# Count: 48640
# Checking segment 150/252
# Line: 68A   Direction: 1
# Count: 16866
# Checking segment 151/252
# Line: 161   Direction: 2
# Count: 7154
# Checking segment 152/252
# Line: 1   Direction: 2
# Count: 664549
# Checking segment 153/252
# Line: 13   Direction: 2
# Count: 1371430
# Checking segment 154/252
# Line: 27B   Direction: 2
# Count: 668750
# Checking segment 155/252
# Line: 16C   Direction: 2
# Count: 12111
# Checking segment 156/252
# Line: 66X   Direction: 1
# Count: 65087
# Checking segment 157/252
# Line: 31B   Direction: 2
# Count: 74437
# Checking segment 158/252
# Line: 54A   Direction: 1
# Count: 400895
# Checking segment 159/252
# Line: 84   Direction: 1
# Count: 448280
# Checking segment 160/252
# Line: 51X   Direction: 2
# Count: 10209
# Checking segment 161/252
# Line: 270   Direction: 1
# Count: 93445
# Checking segment 162/252
# Line: 51D   Direction: 2
# Count: 28665
# Checking segment 163/252
# Line: 38D   Direction: 2
# Count: 2267
# Checking segment 164/252
# Line: 65   Direction: 2
# Count: 346952
# Checking segment 165/252
# Line: 11   Direction: 1
# Count: 736768
# Checking segment 166/252
# Line: 40   Direction: 2
# Count: 2090248
# Checking segment 167/252
# Line: 104   Direction: 2
# Count: 134711
# Checking segment 168/252
# Line: 220   Direction: 2
# Count: 172519
# Checking segment 169/252
# Line: 39   Direction: 2
# Count: 869613
# Checking segment 170/252
# Line: 33X   Direction: 1
# Count: 71864
# Checking segment 171/252
# Line: 56A   Direction: 2
# Count: 255540
# Checking segment 172/252
# Line: 150   Direction: 1
# Count: 510412
# Checking segment 173/252
# Line: 69   Direction: 1
# Count: 304325
# Checking segment 174/252
# Line: 42   Direction: 2
# Count: 702042
# Checking segment 175/252
# Line: 29A   Direction: 2
# Count: 696756
# Checking segment 176/252
# Line: 114   Direction: 2
# Count: 118717
# Checking segment 177/252
# Line: 76   Direction: 1
# Count: 374293
# Checking segment 178/252
# Line: 84A   Direction: 1
# Count: 61939
# Checking segment 179/252
# Line: 15D   Direction: 1
# Count: 16043
# Checking segment 180/252
# Line: 4   Direction: 1
# Count: 937818
# Checking segment 181/252
# Line: 17A   Direction: 2
# Count: 746049
# Checking segment 182/252
# Line: 47   Direction: 2
# Count: 179102
# Checking segment 183/252
# Line: 239   Direction: 1
# Count: 96335
# Checking segment 184/252
# Line: 39X   Direction: 1
# Count: 13473
# Checking segment 185/252
# Line: 67X   Direction: 2
# Count: 81844
# Checking segment 186/252
# Line: 79A   Direction: 2
# Count: 254578
# Checking segment 187/252
# Line: 116   Direction: 2
# Count: 6760
# Checking segment 188/252
# Line: 44   Direction: 1
# Count: 433547
# Checking segment 189/252
# Line: 43   Direction: 2
# Count: 374588
# Checking segment 190/252
# Line: 79   Direction: 2
# Count: 305739
# Checking segment 191/252
# Line: 83   Direction: 1
# Count: 988435
# Checking segment 192/252
# Line: 68X   Direction: 2
# Count: 1971
# Checking segment 193/252
# Line: 151   Direction: 1
# Count: 713254
# Checking segment 194/252
# Line: 63   Direction: 1
# Count: 298075
# Checking segment 195/252
# Line: 53   Direction: 2
# Count: 72951
# Checking segment 196/252
# Line: 70   Direction: 1
# Count: 295552
# Checking segment 197/252
# Line: 41X   Direction: 2
# Count: 38972
# Checking segment 198/252
# Line: 49   Direction: 1
# Count: 449970
# Checking segment 199/252
# Line: 25   Direction: 1
# Count: 195054
# Checking segment 200/252
# Line: 111   Direction: 1
# Count: 162690
# Checking segment 201/252
# Line: 40B   Direction: 1
# Count: 66212
# Checking segment 202/252
# Line: 46E   Direction: 2
# Count: 13774
# Checking segment 203/252
# Line: 41   Direction: 2
# Count: 817963
# Checking segment 204/252
# Line: 83A   Direction: 1
# Count: 266186
# Checking segment 205/252
# Line: 33A   Direction: 2
# Count: 93369
# Checking segment 206/252
# Line: 32X   Direction: 2
# Count: 13390
# Checking segment 207/252
# Line: 38   Direction: 2
# Count: 510051
# Checking segment 208/252
# Line: 27A   Direction: 1
# Count: 376357
# Checking segment 209/252
# Line: 184   Direction: 2
# Count: 320284
# Checking segment 210/252
# Line: 32   Direction: 2
# Count: 409351
# Checking segment 211/252
# Line: 77A   Direction: 1
# Count: 1034842
# Checking segment 212/252
# Line: 41B   Direction: 2
# Count: 57129
# Checking segment 213/252
# Line: 25X   Direction: 1
# Count: 18287
# Checking segment 214/252
# Line: 65B   Direction: 2
# Count: 304470
# Checking segment 215/252
# Line: 61   Direction: 1
# Count: 190254
# Checking segment 216/252
# Line: 14C   Direction: 1
# Count: 7293
# Checking segment 217/252
# Line: 14   Direction: 2
# Count: 1262047
# Checking segment 218/252
# Line: 120   Direction: 2
# Count: 381999
# Checking segment 219/252
# Line: 69X   Direction: 1
# Count: 4912
# Checking segment 220/252
# Line: 7   Direction: 2
# Count: 535956
# Checking segment 221/252
# Line: 26   Direction: 1
# Count: 196583
# Checking segment 222/252
# Line: 145   Direction: 2
# Count: 1865864
# Checking segment 223/252
# Line: 66   Direction: 1
# Count: 619075
# Checking segment 224/252
# Line: 68   Direction: 1
# Count: 381010
# Checking segment 225/252
# Line: 7B   Direction: 1
# Count: 48430
# Checking segment 226/252
# Line: 16   Direction: 2
# Count: 1093884
# Checking segment 227/252
# Line: 25A   Direction: 1
# Count: 528632
# Checking segment 228/252
# Line: 15A   Direction: 2
# Count: 598843
# Checking segment 229/252
# Line: 31D   Direction: 2
# Count: 6264
# Checking segment 230/252
# Line: 33D   Direction: 2
# Count: 2216
# Checking segment 231/252
# Line: 41C   Direction: 1
# Count: 761740
# Checking segment 232/252
# Line: 84X   Direction: 2
# Count: 69236
# Checking segment 233/252
# Line: 66A   Direction: 1
# Count: 225869
# Checking segment 234/252
# Line: 185   Direction: 1
# Count: 99097
# Checking segment 235/252
# Line: 70D   Direction: 1
# Count: 6001
# Checking segment 236/252
# Line: 236   Direction: 2
# Count: 11296
# Checking segment 237/252
# Line: 25B   Direction: 1
# Count: 498921
# Checking segment 238/252
# Line: 142   Direction: 1
# Count: 64887
# Checking segment 239/252
# Line: 76A   Direction: 2
# Count: 20134
# Checking segment 240/252
# Line: 45A   Direction: 1
# Count: 422969
# Checking segment 241/252
# Line: 31   Direction: 1
# Count: 567870
# Checking segment 242/252
# Line: 13   Direction: 1
# Count: 1032430
# Checking segment 243/252
# Line: 38A   Direction: 2
# Count: 402615
# Checking segment 244/252
# Line: 27B   Direction: 1
# Count: 452586
# Checking segment 245/252
# Line: 59   Direction: 1
# Count: 96967
# Checking segment 246/252
# Line: 65   Direction: 1
# Count: 345595
# Checking segment 247/252
# Line: 140   Direction: 2
# Count: 880039
# Checking segment 248/252
# Line: 104   Direction: 1
# Count: 104218
# Checking segment 249/252
# Line: 33E   Direction: 1
# Count: 1452
# Checking segment 250/252
# Line: 238   Direction: 2
# Count: 96241
# Checking segment 251/252
# Line: 102   Direction: 2
# Count: 478736
# Checking segment 252/252
# Line: 46A   Direction: 2
# Count: 2008402
